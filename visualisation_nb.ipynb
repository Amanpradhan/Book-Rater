# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
sns.set_style("white")

# %%
df = pd.read_csv('Processed_Dataset.csv', low_memory=False)

# %%
sns.heatmap(df.corr(), annot=True)

# %%
plt.figure()
plt.hist2d(df['Book-Rating'],df.Age, range=np.array([(0, 10), (0, 150)]) )
plt.show()

# %%
np.mean(df.Age)
# Out:
# 37.30860082802178

# %%
plt.figure()
plt.hist2d(df['Book-Rating'],df["Year-Of-Publication"], range=np.array([(0, 10), (1990, 2010)]) )
plt.show()

# %%
plt.figure()
plt.hist2d(df['Book-Rating'],df["Location"], )
plt.show()
